# %% [markdown]
# # User Data

# %%
# Library Imports
import json
import requests
import pandas as pd
from creds import bearer
# from creds import bearer

# %% [markdown]
# # API Connection

# %%
limit = 50
offset = 0

# apiURL = 'https://api.spotify.com/v1/me/top/tracks?time_range=long_term&limit=50&offset=0'
apiURL = 'https://api.spotify.com/v1/me/top/tracks?time_range=long_term&limit=' + str(limit) + '&offset=' + str(offset) + ''

payload={}
headers = {
  'Content-Type': 'application/json',
  # 'Authorization': 'Bearer BQCEF7Hkxk25BNCgPpjzmH4HxCWSOIUgiqVLFYhanAS4kA9idYlkwhUH5tbH5yI4-cMrtUfAKaxVUGFQtDb70nTSeE2NFwGFhswAMPg3vLnuWphrpL6mfownmMqN6DWmCoJXouMU9kQgEHBmOgee8I4GWwgmk96jgeBxGRROikf67iZMtKFQI8b9OVnAluDdFqI'
  'Authorization': 'Bearer ' + str(bearer)
}

response = requests.request("GET", apiURL, headers=headers, data=payload)

if '401' in str(response):
  print('\n\n\n\n\n\n\nFUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUCK\n\n\n\n\n\n\n')

response
# Out:
# <Response [200]>

# %%
data = json.loads(response.text)

songs = data['items']
# songs

# data['items'][0]

tempdf = pd.DataFrame.from_dict(songs)
# tempdf

# %% [markdown]
# # Column Manipulation

# %%
# tempdf['artists'][30][0]

# A song can have multiple artist but I only want the main artist
for i in range(50):
    
    # print(tempdf['artists'][i][0]['name'])
    # artist_name = tempdf['artists'][i][0]['name']

    tempdf['artists'][i] = tempdf['artists'][i][0]['name']

# artist_name
# tempdf['test'] = new_artist
# Out:
# /var/folders/qp/fkn65nnd78779tktvbsskxr00000gn/T/ipykernel_31335/1898513300.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempdf['artists'][i] = tempdf['artists'][i][0]['name']

# %%
tempdf['duration_ms'] = (tempdf['duration_ms'] / 60000).round(1)

# tempdf

# %% [markdown]
# ## Final Dataset

# %%
data = { 
    "track_id":tempdf['id'],
    "artist":tempdf['artists'],
    "name":tempdf['name'],
    "duration_m":tempdf['duration_ms'],
    "popularity":tempdf['popularity'],
    "explicit":tempdf['explicit'],
    # "sample":tempdf['sample'],
    # "sample":tempdf['sample'],
    # "sample":tempdf['sample'],
}


df = pd.DataFrame(data)

df
# Out:
#                   track_id                 artist  \
# 0   3deMLKUGOk1FTcm2eqPpwI            Spacey Jane
# 1   5A8f466QhliXjJxJ7h6LFB            Spacey Jane
# 2   5HsJGA8P5fPzR06i9FQKBr  The Brook & The Bluff
# 3   5th1bFGGaXLM7wDBJpcF06            Spacey Jane
# 4   1h1CX2ovWU4EJV3ZwlGf2B  The Brook & The Bluff
# 5   65za8SQlRiA88BxZ6Oec4B            Spacey Jane
# 6   3A3meuSBfbpdCiagwbaZIg             DOPE LEMON
# 7   1c5CllrZr45UBhWpIqM332             Thundercat
# 8   1VxJDh3meflUd3Sp3IkcT5            Spacey Jane
# 9   6z7phKqMZakwllYun3zeZZ            Spacey Jane
# 10  1h6xvFLgvoK74l5qMICEDR            Spacey Jane
# 11  1EmB8tvaq9doHobkGzdH3L                Daily J
# 12  0YdIIMb2MHuxoUudkAY9gS      Rex Orange County
# 13  5nVr6ch200sSMaoEYVRPeY         Champagne Lane
# 14  7CMTh1oSr8LIWaTmLExLnj            Spacey Jane
# 15  2tf15sXrdAFhszsDivYSaJ                Daily J
# 16  76c1AuZodByXM3X2k48wju           The Growlers
# 17  4lOmEhpeN25q3a6PUWWx7g                Daily J
# 18  0KbMjhlUH1xUGDgeIQzLsn          Sam Gellaitry
# 19  5JWPUEov2wlX7c0jhYZpeB            Tame Impala
# 20  553ljdFtUKCqS29IblRDeE                Daily J
# 21  5eIarSwTTSZO1qcsLS4pr9            Spacey Jane
# 22  5flMoOfc914PhFtAD8e1gX              Augustine
# 23  5OuJTtNve7FxUX82eEBupN              Peach Pit
# 24  0TPb6ko1z9emzCEFAV9GaZ                Daily J
# 25  0UHDcfnGcluY8ZB5LpAHiF            Spacey Jane
# 26  1e4SU5PsVCaneg9f7hALCh                Daily J
# 27  45XeTqCWLONkwDJkCq3gOg                Daily J
# 28  0rUIff1QHd5zlOBtlHVqd9       The War On Drugs
# 29  6ADSaE87h8Y3lccZlBJdXH                     U2
# 30  57RA3JGafJm5zRtKJiKPIm                Wallows
# 31  16kAQ14aVy5Jo59EJfD5mJ           Tia Gostelow
# 32  7aNW0M1R6eUnoXKpN2HncV                 Reaper
# 33  111HOSfnPX1mCxwwb49BCY            The Killers
# 34  6tnedmxMVEHzPJfWucWzHo          Lime Cordiale
# 35  0frKsr5ann3SLhJBEPqNBP           Way Out West
# 36  66tkDkPsznE5zIHNt4QkXB                Parcels
# 37  5EYi2rH4LYs6M21ZLOyQTx      Rex Orange County
# 38  4d7ifHr1zrli3fOi9aIHax  The Brook & The Bluff
# 39  1Uxti0PEEdieT526B8dAxZ                Parcels
# 40  2a2Yb7fc67EzRUVpYTUyZq                 Lane 8
# 41  3OquIgAWGnNPg0eJqUT0EF            Mild Orange
# 42  7oekneJCJO74ycdLzdk16v              Vance Joy
# 43  3mCjMGGea0h42M4kOvykXA                   COIN
# 44  43xKeURnATYLC9EnaouOqU           Tia Gostelow
# 45  1GkHyypTFkUf0QQKwYoXH4           benny blanco
# 46  50kXxYwLylVddXQaiGMck1            Still Woozy
# 47  2g9LXMNIBCqmngHpH9nXv0             Lord Huron
# 48  6VG8grbdAIo1RDXmTA6yRs                Daily J
# 49  7LqfaS1QNYDYIxZSr9XpE6            Mild Orange
#
#                                          name  duration_m  popularity  \
# 0                        It's Been a Long Day         4.1          31
# 1                             Lots of Nothing         3.3          35
# 2                                  Halfway Up         3.9          56
# 3                                Booster Seat         4.5          45
# 4                                      Shelby         3.7          50
# 5                                         Yet         3.4          29
# 6                        Streets Of Your Town         3.5          52
# 7                                 Funny Thing         1.9          74
# 8                                Clean My Car         3.3          28
# 9                                     Hanging         3.4          22
# 10                         Feeding the Family         4.7          40
# 11                                 Letting Go         4.1          32
# 12                               Face to Face         3.7          60
# 13                             Feelin' It Out         4.1          38
# 14                                  Hardlight         3.6          27
# 15                                     Rocket         3.7          53
# 16                             Dope on a Rope         4.2          60
# 17                        Left Me Like Summer         4.8          58
# 18                                        Duo         2.1          53
# 19                          Lost In Yesterday         4.2          67
# 20                                      Space         3.5          57
# 21                               Feels Better         4.6          20
# 22                                       Prom         2.8          39
# 23                              Tommy's Party         6.0          66
# 24                                     Skylah         3.3          56
# 25                                    Haircut         3.7          25
# 26                             Sunshine Hides         4.2          39
# 27                                 Had It All         4.0          29
# 28                                   Red Eyes         5.0          65
# 29           With Or Without You - Remastered         4.9          79
# 30          Are You Bored Yet? (feat. Clairo)         3.0          79
# 31                                     Giants         3.9          27
# 32                                      HEADY         3.5           0
# 33                                    Caution         4.5          59
# 34                                 On Our Own         3.6          44
# 35  Lullaby Horizon - Ben Böhmer Extended Mix         6.5          19
# 36                             Tieduprightnow         4.2          70
# 37         Loving Is Easy (feat. Benny Sings)         2.6          53
# 38                                   Misnomer         3.7          24
# 39                           Somethinggreater         5.4          56
# 40                                  Grapevine         6.4          56
# 41                             This Kinda Day         4.6          14
# 42                               Lay It on Me         3.6          58
# 43                                  Babe Ruth         3.2          36
# 44                                  Strangers         3.0          43
# 45          You (with Marshmello & Vance Joy)         2.8          63
# 46                                       Woof         2.6          54
# 47                          Wait by the River         3.2          56
# 48                             Talking to You         3.6          49
# 49           The Time of Our Lives - Extended         5.0           8
#
#     explicit
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14      True
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22      True
# 23      True
# 24     False
# 25      True
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37      True
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False

# %% [markdown]
# ## Audio Feature Retrieval
